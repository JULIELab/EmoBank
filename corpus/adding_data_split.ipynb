# %% [markdown]
# # Adding a Stratified Train-Dev-Test Split to EmoBank

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
eb = pd.read_csv('emobank.csv', index_col=0)

# %%
eb
# Out:
#                         V     A     D  \
# id
# 110CYL068_1036_1079  3.00  3.00  3.20
# 110CYL068_1079_1110  2.80  3.10  2.80
# 110CYL068_1127_1130  3.00  3.00  3.00
# 110CYL068_1137_1188  3.44  3.00  3.22
# 110CYL068_1189_1328  3.55  3.27  3.46
# ...                   ...   ...   ...
# wwf12_4531_4624      3.00  3.50  3.00
# wwf12_501_591        3.80  3.40  3.60
# wwf12_592_691        3.00  3.00  3.10
# wwf12_702_921        3.33  3.44  3.44
# wwf12_932_1053       3.43  3.71  3.29
#
#                                                                   text
# id
# 110CYL068_1036_1079        Remember what she said in my last letter? "
# 110CYL068_1079_1110                          If I wasn't working here.
# 110CYL068_1127_1130                                                .."
# 110CYL068_1137_1188  Goodwill helps people get off of public assist...
# 110CYL068_1189_1328  Sherry learned through our Future Works class ...
# ...                                                                ...
# wwf12_4531_4624      Please let it be a constant reminder of all yo...
# wwf12_501_591        That’s why I want to extend my appreciation fo...
# wwf12_592_691        And why I’m writing you today to ask you to re...
# wwf12_702_921        In fact, I want to urge you to strengthen your...
# wwf12_932_1053       With your increased commitment, we can move fo...
#
# [10062 rows x 4 columns]

# %%
meta = pd.read_csv('meta.tsv', sep='\t', index_col=0)

# %%
meta
# Out:
#                                                 document category subcategory
# id
# Acephalous-Cant-believe_4_47     Acephalous-Cant-believe     blog
# Acephalous-Cant-believe_83_354   Acephalous-Cant-believe     blog
# Acephalous-Cant-believe_355_499  Acephalous-Cant-believe     blog
# Acephalous-Cant-believe_500_515  Acephalous-Cant-believe     blog
# Acephalous-Cant-believe_517_626  Acephalous-Cant-believe     blog
# ...                                                  ...      ...         ...
# SemEval_1495                                     SemEval  SemEval         NaN
# SemEval_1496                                     SemEval  SemEval         NaN
# SemEval_1497                                     SemEval  SemEval         NaN
# SemEval_1498                                     SemEval  SemEval         NaN
# SemEval_1499                                     SemEval  SemEval         NaN
#
# [10548 rows x 3 columns]

# %%
meta.category.value_counts()
# Out:
# fiction          2893
# letters          1479
# newspaper        1381
# blog             1378
# SemEval          1250
# essays           1196
# travel-guides     971
# Name: category, dtype: int64

# %%
eb = eb.join(meta, how='inner')

# %%
eb
# Out:
#                         V     A     D  \
# id
# 110CYL068_1036_1079  3.00  3.00  3.20
# 110CYL068_1079_1110  2.80  3.10  2.80
# 110CYL068_1127_1130  3.00  3.00  3.00
# 110CYL068_1137_1188  3.44  3.00  3.22
# 110CYL068_1189_1328  3.55  3.27  3.46
# ...                   ...   ...   ...
# wwf12_4531_4624      3.00  3.50  3.00
# wwf12_501_591        3.80  3.40  3.60
# wwf12_592_691        3.00  3.00  3.10
# wwf12_702_921        3.33  3.44  3.44
# wwf12_932_1053       3.43  3.71  3.29
#
#                                                                   text  \
# id
# 110CYL068_1036_1079        Remember what she said in my last letter? "
# 110CYL068_1079_1110                          If I wasn't working here.
# 110CYL068_1127_1130                                                .."
# 110CYL068_1137_1188  Goodwill helps people get off of public assist...
# 110CYL068_1189_1328  Sherry learned through our Future Works class ...
# ...                                                                ...
# wwf12_4531_4624      Please let it be a constant reminder of all yo...
# wwf12_501_591        That’s why I want to extend my appreciation fo...
# wwf12_592_691        And why I’m writing you today to ask you to re...
# wwf12_702_921        In fact, I want to urge you to strengthen your...
# wwf12_932_1053       With your increased commitment, we can move fo...
#
#                       document category                subcategory
# id
# 110CYL068_1036_1079  110CYL068  letters  philanthropic-fundraising
# 110CYL068_1079_1110  110CYL068  letters  philanthropic-fundraising
# 110CYL068_1127_1130  110CYL068  letters  philanthropic-fundraising
# 110CYL068_1137_1188  110CYL068  letters  philanthropic-fundraising
# 110CYL068_1189_1328  110CYL068  letters  philanthropic-fundraising
# ...                        ...      ...                        ...
# wwf12_4531_4624          wwf12  letters     solicitation-brochures
# wwf12_501_591            wwf12  letters     solicitation-brochures
# wwf12_592_691            wwf12  letters     solicitation-brochures
# wwf12_702_921            wwf12  letters     solicitation-brochures
# wwf12_932_1053           wwf12  letters     solicitation-brochures
#
# [10062 rows x 7 columns]

# %%
tmp, test = train_test_split(eb.index, stratify=eb.category, random_state=42, test_size=1000)
train, dev = train_test_split(tmp, stratify=eb.loc[tmp].category, random_state=42, test_size=1000)

# %%
print(len(train), len(dev), len(test))
# Out:
# 8062 1000 1000

# %%
relfreqs = {}
splits = {'train':train, 'dev': dev, 'test':test}
for key, split in splits.items():
    relfreqs[key] = eb.loc[split].category.value_counts() / len(split)
pd.DataFrame(relfreqs).round(3)
# Out:
#                train    dev   test
# fiction        0.274  0.274  0.274
# letters        0.141  0.140  0.140
# blog           0.133  0.133  0.133
# newspaper      0.130  0.131  0.131
# SemEval        0.119  0.118  0.118
# essays         0.113  0.113  0.113
# travel-guides  0.091  0.091  0.091

# %%
for key, split in splits.items():
    eb.loc[split, 'split'] = key

# %%
eb = eb.drop(columns=['document', 'category', 'subcategory'])

# %%
eb = eb[['split', 'V', 'A', 'D', 'text']]

# %%
eb
# Out:
#                      split     V     A     D  \
# id
# 110CYL068_1036_1079  train  3.00  3.00  3.20
# 110CYL068_1079_1110   test  2.80  3.10  2.80
# 110CYL068_1127_1130  train  3.00  3.00  3.00
# 110CYL068_1137_1188  train  3.44  3.00  3.22
# 110CYL068_1189_1328  train  3.55  3.27  3.46
# ...                    ...   ...   ...   ...
# wwf12_4531_4624      train  3.00  3.50  3.00
# wwf12_501_591        train  3.80  3.40  3.60
# wwf12_592_691        train  3.00  3.00  3.10
# wwf12_702_921        train  3.33  3.44  3.44
# wwf12_932_1053       train  3.43  3.71  3.29
#
#                                                                   text
# id
# 110CYL068_1036_1079        Remember what she said in my last letter? "
# 110CYL068_1079_1110                          If I wasn't working here.
# 110CYL068_1127_1130                                                .."
# 110CYL068_1137_1188  Goodwill helps people get off of public assist...
# 110CYL068_1189_1328  Sherry learned through our Future Works class ...
# ...                                                                ...
# wwf12_4531_4624      Please let it be a constant reminder of all yo...
# wwf12_501_591        That’s why I want to extend my appreciation fo...
# wwf12_592_691        And why I’m writing you today to ask you to re...
# wwf12_702_921        In fact, I want to urge you to strengthen your...
# wwf12_932_1053       With your increased commitment, we can move fo...
#
# [10062 rows x 5 columns]

# %%
eb.to_csv('emobank.csv')

# %% [markdown]
# ---
